# %% [markdown]
# ### 모듈3 과정에 나오는 코드 실습

# %%
# 1차원 벡터

import numpy as np
a = np.array([2,1])
print(a)
type(a)
# Out:
# [2 1]
# numpy.ndarray

# %%
# 2차원 벡터

c = np.array([[1,2],[3,4]])
print(c)
d = np.array([[1],[2]])
print(d)
# Out:
# [[1 2]
#  [3 4]]
# [[1]
#  [2]]

# %%
# 벡터의 내적

b = np.array([1,3])
c = np.array([4,2])
print(b.dot(c))
# Out:
# 10

# %%
# 벡터 합을 내적으로 계산하기

import datetime as dt

stamp1 = dt.datetime.now()
a = np.ones(1000) # [1,1,1...1]
b = np.arange(1,1001) # [1,2,3,....,1000]
print(a.dot(b))

stamp2 = dt.datetime.now()
# 프로세스 처리전 시간과 처리후 시간의 차이가 총 프로세스 처리시간이 된다.
print(stamp2-stamp1)
# Out:
# 500500.0
# 0:00:00.000497

# %%
stamp3 = dt.datetime.now()

a = np.ones(1000) # [1,1,1...1]
b = np.arange(1,1001) # [1,2,3,....,1000]

c = sum(i*j for i,j in zip(a,b))
print(c)

stamp4 = dt.datetime.now()
print(stamp4-stamp3)

# dot product in for loop
# zip(a,b) 해준 것을 전체 합하면 된다

# for i in range(len(a)) :
#     c = a[i]+b[i]
# Out:
# 500500.0
# 0:00:00.000496

# %%
# 편미분
# f를 동고선으로 표시하고, w의 공간을 격자형으로 나눴을 때 각 점에서의 경사를 화살표로 그림

import matplotlib.pyplot as plt

def f (w0, w1) :# (A) f의 정의
    return w0**2 + 2 * 2 * w0 *w1 + 3
def df_dw0(w0, w1) : # (B) f의 w0에 대한 편미분
    return 2* w0 + 2* w1
def df_dw1(wo, w1) : # (C) f의 w1에 대한 편미분
    return 2 * w0 + 0 * w1

w_range = 2
dw = 0.25

w0 = np.arange(-w_range, w_range + dw, dw)
w1 = np.arange(-w_range, w_range + dw, dw)
wn = w0.shape[0]

ww0, ww1 = np.meshgrid(w0, w1) # (D)
ff = np.zeros((len(w0), len(w1)))
dff_dw0 = np.zeros((len(w0), len(w1)))
dff_dw1 = np.zeros((len(w0), len(w1)))

for i0 in range(wn) : # (E)
    for i1 in range(wn) :
        ff[i1, i0] = f(w0[i0], w1[i1])
        dff_dw0[i1, i0] = df_dw0(w0[i0], w1[i1])
        dff_dw1[i1, i0] = df_dw0(w0[i0], w1[i1])
        
plt.figure(figsize=(9,4))
plt.subplots_adjust(wspace=0.3)
plt.subplot(1,2,1)

cont = plt.contour(ww0, ww1, ff, 10, colors='k') # (F) f의 등고선 표시
cont.clabel(fmt='%2.0f', fontsize=0)

plt.xticks(range(-w_range, w_range+1, 1))
plt.yticks(range(-w_range, w_range+1, 1))
plt.xlim(-w_range - 0.5, w_range + .5)
plt.ylim(-w_range - .5, w_range + .5)
plt.xlabel('$w_0$', fontsize=14) # 달러 표시 : 마크업 문서 작성시 레이텍스 언어
plt.ylabel('$w_1$', fontsize=14)
plt.subplot(1,2,2)

plt.quiver(ww0, ww1, dff_dw0, dff_dw1) # (G) f의 경사 벡터 표시
plt.xlabel('$w_0$', fontsize=14)
plt.ylabel('$w_1$', fontsize=14)
plt.xticks(range(-w_range, w_range+1, 1))
plt.yticks(range(-w_range, w_range+1, 1))
plt.xlim(-w_range - 0.5, w_range + .5)
plt.ylim(-w_range - .5, w_range + .5)

plt.show()
